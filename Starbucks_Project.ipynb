# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv("starbucks.csv", index_col = 0)
data.head()
# Out:
#                           item  calories   fat  carb  fiber  protein    type
# 1                 8-Grain Roll       350   8.0    67      5       10  bakery
# 2            Apple Bran Muffin       350   9.0    64      7        6  bakery
# 3                Apple Fritter       420  20.0    59      0        5  bakery
# 4              Banana Nut Loaf       490  19.0    75      4        7  bakery
# 5  Birthday Cake Mini Doughnut       130   6.0    17      0        0  bakery

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77 entries, 1 to 77
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item      77 non-null     object
#  1   calories  77 non-null     int64
#  2   fat       77 non-null     float64
#  3   carb      77 non-null     int64
#  4   fiber     77 non-null     int64
#  5   protein   77 non-null     int64
#  6   type      77 non-null     object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 4.8+ KB

# %%
data.describe()
# Out:
#          calories        fat       carb      fiber    protein
# count   77.000000  77.000000  77.000000  77.000000  77.000000
# mean   338.831169  13.766234  44.870130   2.220779   9.480519
# std    105.368701   7.095488  16.551634   2.112764   8.079556
# min     80.000000   0.000000  16.000000   0.000000   0.000000
# 25%    300.000000   9.000000  31.000000   0.000000   5.000000
# 50%    350.000000  13.000000  45.000000   2.000000   7.000000
# 75%    420.000000  18.000000  59.000000   4.000000  15.000000
# max    500.000000  28.000000  80.000000   7.000000  34.000000

# %%
data.isnull().sum()
# Out:
# item        0
# calories    0
# fat         0
# carb        0
# fiber       0
# protein     0
# type        0
# dtype: int64

# %%
data.nunique()
# Out:
# item        77
# calories    29
# fat         31
# carb        49
# fiber        7
# protein     26
# type         7
# dtype: int64

# %%
data.shape
# Out:
# (77, 7)

# %%
data.groupby(["type"])["calories","fat","carb","protein","fiber"].aggregate("mean")
# Out:
# C:\Users\Mert AYDIN\AppData\Local\Temp\ipykernel_11112\610301705.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(["type"])["calories","fat","carb","protein","fiber"].aggregate("mean")
#                  calories        fat       carb    protein     fiber
# type
# bakery         368.780488  14.560976  54.341463   5.926829  1.951220
# bistro box     377.500000  18.375000  33.625000  19.125000  5.125000
# hot breakfast  325.000000  13.687500  33.250000  16.125000  2.250000
# parfait        300.000000   6.500000  53.666667   8.333333  2.000000
# petite         177.777778   9.333333  23.333333   1.111111  0.000000
# salad           80.000000   0.000000  20.000000   0.000000  2.000000
# sandwich       395.714286  14.714286  43.000000  24.285714  3.428571

# %%
data.groupby(["type"])["item"].count()
# Out:
# type
# bakery           41
# bistro box        8
# hot breakfast     8
# parfait           3
# petite            9
# salad             1
# sandwich          7
# Name: item, dtype: int64

# %%
data.groupby(["type"])["item"].count().plot(figsize = (8,4))
plt.title("Types Of Products")
plt.show()

# %%
sb.countplot(x = "type", data = data)
plt.title("Types Of Products")
plt.show()

# %%
sb.catplot(y = "type", x = "calories", kind = "bar", data = data)
plt.title("Values Of Calorie")
plt.show()

# %%
sb.catplot(y = "type", x = "fat", kind = "bar", data = data)
plt.title("Values Of Calorie")
plt.show()

# %%
sb.catplot(y = "type", x = "carb", kind = "bar", data = data)
plt.title("Values Of Calorie")
plt.show()

# %%
sb.catplot(y = "type", x = "fiber", kind = "bar", data = data)
plt.title("Values Of Calorie")
plt.show()

# %%
sb.catplot(y = "type", x = "protein", kind = "bar", data = data)
plt.title("Values Of Calorie")
plt.show()

# %%
data.corr()
# Out:
# C:\Users\Mert AYDIN\AppData\Local\Temp\ipykernel_11112\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#           calories       fat      carb     fiber   protein
# calories  1.000000  0.758682  0.674999  0.260645  0.410398
# fat       0.758682  1.000000  0.144547 -0.028549  0.223470
# carb      0.674999  0.144547  1.000000  0.213044 -0.050789
# fiber     0.260645 -0.028549  0.213044  1.000000  0.488564
# protein   0.410398  0.223470 -0.050789  0.488564  1.000000

# %%
sb.heatmap(data.corr(), annot = True);
# Out:
# C:\Users\Mert AYDIN\AppData\Local\Temp\ipykernel_11112\1819875681.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(data.corr(), annot = True);

# %%
sb.scatterplot(x = "calories", y = "fat", data = data, s = 20, edgecolor = "red");

# %%
sb.scatterplot(x = "calories", y = "fiber", data = data, s = 20, edgecolor = "red");

# %%
sb.scatterplot(x = "calories", y = "protein", data = data, s = 20, edgecolor = "red");

# %%
sb.scatterplot(x = "calories", y = "carb", data = data, s = 20, edgecolor = "red");

# %%
sb.displot(x = "calories", data = data, color = "yellow");
plt.title("Calorie Diagram")
plt.show()

# %%
sb.displot(x = "fiber", data = data, color = "green");
plt.title("Fiber Diagram")
plt.show()

# %%
sb.displot(x = "fat", data = data, color = "red");
plt.title("Fat Diagram")
plt.show()

# %%
sb.displot(x = "protein", data = data, color = "violet");
plt.title("Protein Diagram")
plt.show()

# %%
sb.displot(x = "carb", data = data, color = "lightblue");
plt.title("Carb Diagram")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
x = data[["calories","fat","carb","fiber","protein"]]
y = data[["type"]]

# %%
x.head()
# Out:
#    calories   fat  carb  fiber  protein
# 1       350   8.0    67      5       10
# 2       350   9.0    64      7        6
# 3       420  20.0    59      0        5
# 4       490  19.0    75      4        7
# 5       130   6.0    17      0        0

# %%
y.head()
# Out:
#      type
# 1  bakery
# 2  bakery
# 3  bakery
# 4  bakery
# 5  bakery

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size = 0.8, random_state = 10)

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_prediction = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_prediction)
print(f"Accuracy : %{accuracy * 100}")
# Out:
# Accuracy : %81.25

# %%
prediction = model.predict([[250, 2, 40, 7, 9]])
print(f"Prediction : {prediction}")
# Out:
# Prediction : ['parfait']
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
plt.figure(figsize = (15,10))
plot_tree(model, feature_names = x.columns, class_names = model.classes_, filled = True);
