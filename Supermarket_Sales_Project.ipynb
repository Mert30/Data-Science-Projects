# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv("supermarket_sales.csv")
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
data.describe().T
# Out:
#               count          mean           std       min        25%  \
# Row ID       9800.0   4900.500000   2829.160653     1.000   2450.750
# Postal Code  9789.0  55273.322403  32041.223413  1040.000  23223.000
# Sales        9800.0    230.769059    626.651875     0.444     17.248
#
#                   50%        75%       max
# Row ID        4900.50   7350.250   9800.00
# Postal Code  58103.00  90008.000  99301.00
# Sales           54.49    210.605  22638.48

# %%
data.nunique()
# Out:
# Row ID           9800
# Order ID         4922
# Order Date       1230
# Ship Date        1326
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              529
# State              49
# Postal Code       626
# Region              4
# Product ID       1861
# Category            3
# Sub-Category       17
# Product Name     1849
# Sales            5757
# dtype: int64

# %%
data.shape
# Out:
# (9800, 18)

# %%
data.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
data = data.drop(["Row ID","Order ID","Product ID","Customer ID"], axis = 1)
data.head()
# Out:
#    Order Date   Ship Date       Ship Mode    Customer Name    Segment  \
# 0  08/11/2017  11/11/2017    Second Class      Claire Gute   Consumer
# 1  08/11/2017  11/11/2017    Second Class      Claire Gute   Consumer
# 2  12/06/2017  16/06/2017    Second Class  Darrin Van Huff  Corporate
# 3  11/10/2016  18/10/2016  Standard Class   Sean O'Donnell   Consumer
# 4  11/10/2016  18/10/2016  Standard Class   Sean O'Donnell   Consumer
#
#          Country             City       State  Postal Code Region  \
# 0  United States        Henderson    Kentucky      42420.0  South
# 1  United States        Henderson    Kentucky      42420.0  South
# 2  United States      Los Angeles  California      90036.0   West
# 3  United States  Fort Lauderdale     Florida      33311.0  South
# 4  United States  Fort Lauderdale     Florida      33311.0  South
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# ...

# %%
data[data["Postal Code"].isnull()]
# Out:
#       Order Date   Ship Date       Ship Mode     Customer Name      Segment  \
# 2234  05/12/2018  10/12/2018  Standard Class      Quincy Jones    Corporate
# 5274  07/11/2016  09/11/2016    Second Class  Stewart Visinsky     Consumer
# 8798  06/04/2017  10/04/2017  Standard Class   Valerie Mitchum  Home Office
# 9146  23/01/2017  27/01/2017  Standard Class  Claudia Bergmann    Corporate
# 9147  23/01/2017  27/01/2017  Standard Class  Claudia Bergmann    Corporate
# 9148  23/01/2017  27/01/2017  Standard Class  Claudia Bergmann    Corporate
# 9386  19/01/2018  23/01/2018  Standard Class     Raymond Messe     Consumer
# 9387  19/01/2018  23/01/2018  Standard Class     Raymond Messe     Consumer
# 9388  19/01/2018  23/01/2018  Standard Class     Raymond Messe     Consumer
# 9389  19/01/2018  23/01/2018  Standard Class     Raymond Messe     Consumer
# 9741  08/11/2016  12/11/2016  Standard Class      Quincy Jones    Corporate
#
# ...

# %%
data["Postal Code"] = data["Postal Code"].fillna(5402)

# %%
data.isnull().sum()
# Out:
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
d = {1: "January", 2:"February", 3:"March", 4:"April", 5:"May", 6:"June", 7:"July", 8:"August", 9:"September", 10:"October", 11:"November", 12:"December"}
d
# Out:
# {1: 'January',
#  2: 'February',
#  3: 'March',
#  4: 'April',
#  5: 'May',
#  6: 'June',
#  7: 'July',
#  8: 'August',
#  9: 'September',
#  10: 'October',
#  11: 'November',
#  12: 'December'}

# %%
data["Month"] = data["Order Date"].str[3:5]
data["Month"] = data["Month"].astype("int32")
data["Month"] = [d[i] for i in data["Month"]]
data.head()
# Out:
#    Order Date   Ship Date       Ship Mode    Customer Name    Segment  \
# 0  08/11/2017  11/11/2017    Second Class      Claire Gute   Consumer
# 1  08/11/2017  11/11/2017    Second Class      Claire Gute   Consumer
# 2  12/06/2017  16/06/2017    Second Class  Darrin Van Huff  Corporate
# 3  11/10/2016  18/10/2016  Standard Class   Sean O'Donnell   Consumer
# 4  11/10/2016  18/10/2016  Standard Class   Sean O'Donnell   Consumer
#
#          Country             City       State  Postal Code Region  \
# 0  United States        Henderson    Kentucky      42420.0  South
# 1  United States        Henderson    Kentucky      42420.0  South
# 2  United States      Los Angeles  California      90036.0   West
# 3  United States  Fort Lauderdale     Florida      33311.0  South
# 4  United States  Fort Lauderdale     Florida      33311.0  South
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# ...

# %%
data["Order Date"] = pd.to_datetime(data["Order Date"])
# Out:
# C:\Users\Mert AYDIN\AppData\Local\Temp\ipykernel_1564\189678970.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data["Order Date"] = pd.to_datetime(data["Order Date"])

# %%
data["Ship Date"] = pd.to_datetime(data["Ship Date"])
# Out:
# C:\Users\Mert AYDIN\AppData\Local\Temp\ipykernel_1564\3627617225.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data["Ship Date"] = pd.to_datetime(data["Ship Date"])

# %%
data["Year"] = data["Order Date"].dt.year

# %%
data.head()
# Out:
#   Order Date  Ship Date       Ship Mode    Customer Name    Segment  \
# 0 2017-08-11 2017-11-11    Second Class      Claire Gute   Consumer
# 1 2017-08-11 2017-11-11    Second Class      Claire Gute   Consumer
# 2 2017-12-06 2017-06-16    Second Class  Darrin Van Huff  Corporate
# 3 2016-11-10 2016-10-18  Standard Class   Sean O'Donnell   Consumer
# 4 2016-11-10 2016-10-18  Standard Class   Sean O'Donnell   Consumer
#
#          Country             City       State  Postal Code Region  \
# 0  United States        Henderson    Kentucky      42420.0  South
# 1  United States        Henderson    Kentucky      42420.0  South
# 2  United States      Los Angeles  California      90036.0   West
# 3  United States  Fort Lauderdale     Florida      33311.0  South
# 4  United States  Fort Lauderdale     Florida      33311.0  South
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# ...

# %%
data["Year"].value_counts()
# Out:
# 2018    3258
# 2017    2534
# 2016    2055
# 2015    1953
# Name: Year, dtype: int64

# %%
sb.countplot(x = data["Year"], data = data);

# %%
data["Month"].value_counts()
# Out:
# November     1449
# December     1382
# September    1354
# October       809
# May           725
# July          697
# August        693
# June          691
# March         680
# April         657
# January       366
# February      297
# Name: Month, dtype: int64

# %%
sb.countplot(y = data["Month"], data = data);

# %%
month_sales = data.groupby("Month").sum()
month_sales = month_sales[["Sales"]]
month_sales
# Out:
# C:\Users\Mert AYDIN\AppData\Local\Temp\ipykernel_1564\3793857287.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   month_sales = data.groupby("Month").sum()
#                  Sales
# Month
# April      136283.0006
# August     157315.9270
# December   321480.1695
# February    59371.1154
# January     94291.6296
# July       145535.6890
# June       145837.5233
# March      197573.5872
# May        154086.7237
# November   350161.7110
# October    199496.2947
# September  300103.4117

# %%
month_sales.reset_index(inplace = True)

# %%
sb.barplot(data = month_sales, x = month_sales["Sales"], y = month_sales["Month"]);

# %%
year_sales = data.groupby("Year").sum()
year_sales = year_sales[["Sales"]]
year_sales
# Out:
# C:\Users\Mert AYDIN\AppData\Local\Temp\ipykernel_1564\814710016.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   year_sales = data.groupby("Year").sum()
#             Sales
# Year
# 2015  479856.2081
# 2016  459436.0054
# 2017  600192.5500
# 2018  722052.0192

# %%
year_sales.reset_index(inplace = True)

# %%
sb.barplot(data = year_sales, y = year_sales["Sales"], x = year_sales["Year"]);

# %%
customer= data.groupby("Customer Name").sum().sort_values("Sales", ascending = False)
customer.drop(["Postal Code","Year"], axis = 1, inplace = True)
customer.reset_index(inplace = True)
customer
# Out:
# C:\Users\Mert AYDIN\AppData\Local\Temp\ipykernel_1564\4164444753.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   customer= data.groupby("Customer Name").sum().sort_values("Sales", ascending = False)
#        Customer Name      Sales
# 0        Sean Miller  25043.050
# 1       Tamara Chand  19052.218
# 2       Raymond Buch  15117.339
# 3       Tom Ashbrook  14595.620
# 4      Adrian Barton  14473.571
# ..               ...        ...
# 788  Mitch Gastineau     16.739
# 789     Carl Jackson     16.520
# 790       Sung Chung     14.112
# 791     Lela Donovan      5.304
# 792    Thais Sissman      4.833
#
# [793 rows x 2 columns]

# %%
customer = customer.head(20)
plt.bar(customer["Customer Name"], customer["Sales"])
plt.xlabel("Names")
plt.ylabel("Sales")
plt.xticks(fontsize = 11, rotation = 90)
plt.show()

# %%
category = data.groupby("Category").sum()
category = category[["Sales"]]
category.reset_index(inplace = True)
category
# Out:
# C:\Users\Mert AYDIN\AppData\Local\Temp\ipykernel_1564\3678950576.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   category = data.groupby("Category").sum()
#           Category        Sales
# 0        Furniture  728658.5757
# 1  Office Supplies  705422.3340
# 2       Technology  827455.8730

# %%
plt.bar(category["Category"], category["Sales"])
plt.xlabel("Category")
plt.ylabel("Sales")
plt.show()

# %%
plt.pie(category["Sales"], labels = category["Category"], autopct = "%0.2f%%")
plt.show()
